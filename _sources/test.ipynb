# %% [markdown]
# # This a jupyter notebook

# %%
import numpy as np

t = np.linspace(-np.pi,np.pi,100)
y = np.sin(t)

# %% [markdown]
# some text here

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(t,y, '.-')
